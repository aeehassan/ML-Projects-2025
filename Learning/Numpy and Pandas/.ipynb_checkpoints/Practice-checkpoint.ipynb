# %% [markdown]
# # Numpy practice

# %%
import numpy as np

# %%
a = np.array([1,2])

# %%
b = np.array([[1,2],[1,2]])

# %%
np.sum(a)
# Out:
# np.int64(3)

# %%
np.sum(b)
# Out:
# np.int64(6)

# %%
np.sum(b,axis=0)
# Out:
# array([2, 4])

# %%
np.sum(b,axis=1)
# Out:
# array([3, 3])

# %%
a+a
# Out:
# array([2, 4])

# %%
a-a
# Out:
# array([0, 0])

# %%
a*a
# Out:
# array([1, 4])

# %%
a**2
# Out:
# array([1, 4])

# %%
np.sqrt(b)
# Out:
# array([[1.        , 1.41421356],
#        [1.        , 1.41421356]])

# %%
np.square(b)
# Out:
# array([[1, 4],
#        [1, 4]])

# %%
np.mean(b)
# Out:
# np.float64(1.5)

# %%
np.std(b)
# Out:
# np.float64(0.5)

# %%
np.var(b)
# Out:
# np.float64(0.25)

# %% [markdown]
# ## Array attributes

# %%
b.ndim
# Out:
# 2

# %%
b.size
# Out:
# 4

# %%
b.shape
# Out:
# (2, 2)

# %%
b.dtype
# Out:
# dtype('int64')

# %% [markdown]
# # Pandas practice

# %%
import pandas as pd

# %%
s = pd.Series([1,2,3,4],['a','b','c','d'])

# %%
s
# Out:
# a    1
# b    2
# c    3
# d    4
# dtype: int64

# %%
df = pd.DataFrame({
    'Reg' : ['1001','1002','1003','1004','1005'],
    'CGPA': [5.00,5.00,4.99,4.97,4.94],
    'Age' : ['19','20','18','21','19']
})

# %%
df
# Out:
#     Reg  CGPA Age
# 0  1001  5.00  19
# 1  1002  5.00  20
# 2  1003  4.99  18
# 3  1004  4.97  21
# 4  1005  4.94  19

# %%
df.head()
# Out:
#     Reg  CGPA Age
# 0  1001  5.00  19
# 1  1002  5.00  20
# 2  1003  4.99  18
# 3  1004  4.97  21
# 4  1005  4.94  19

# %%
df = pd.read_csv('metro-trips-2025-q1.csv')

# %%
df
# Out:
#          trip_id  duration       start_time         end_time  start_station  \
# 0      475609834         5    1/1/2025 0:12    1/1/2025 0:17           3030
# 1      475609846         7    1/1/2025 0:12    1/1/2025 0:19           4558
# 2      475609903        11    1/1/2025 0:13    1/1/2025 0:24           4212
# 3      475609904        11    1/1/2025 0:13    1/1/2025 0:24           4212
# 4      475610048        13    1/1/2025 0:27    1/1/2025 0:40           4472
# ...          ...       ...              ...              ...            ...
# 95911  497792778        13  3/31/2025 23:43  3/31/2025 23:56           3022
# 95912  497792596         7  3/31/2025 23:44  3/31/2025 23:51           4643
# 95913  497792744         6  3/31/2025 23:49  3/31/2025 23:55           3026
# 95914  497826163       623  3/31/2025 23:56   4/1/2025 10:19           3035
# 95915  497794483        17  3/31/2025 23:59    4/1/2025 0:16           4584
#
# ...

# %%
df.shape
# Out:
# (95916, 15)

# %%
df.ndim
# Out:
# 2

# %%
df.size
# Out:
# 1438740

# %%
df.dtypes
# Out:
# trip_id                  int64
# duration                 int64
# start_time              object
# end_time                object
# start_station            int64
# start_lat              float64
# start_lon              float64
# end_station              int64
# end_lat                float64
# end_lon                float64
# bike_id                  int64
# plan_duration            int64
# trip_route_category     object
# passholder_type         object
# bike_type               object
# dtype: object

# %%
df.describe()
# Out:
#             trip_id      duration  start_station     start_lat     start_lon  \
# count  9.591600e+04  95916.000000   95916.000000  95897.000000  95897.000000
# mean   4.877870e+08     29.596251    4032.004212     34.037871   -118.343739
# std    6.767440e+06     89.771361     648.376810      0.034939      0.092518
# min    4.756098e+08      1.000000    3000.000000     33.928459   -118.491341
# 25%    4.817609e+08      7.000000    3068.000000     34.022091   -118.445351
# 50%    4.881078e+08     14.000000    4273.000000     34.045021   -118.291718
# 75%    4.943926e+08     26.000000    4543.000000     34.056610   -118.258537
# max    4.984209e+08   1440.000000    4692.000000     34.177650   -118.225410
#
#         end_station       end_lat       end_lon       bike_id  plan_duration
# count  95916.000000  93410.000000  93410.000000  95916.000000   95916.000000
# mean    4006.413904     34.037465   -118.344293  19171.512897      57.631792
# ...

# %%
df.isna().sum()
# Out:
# trip_id                   0
# duration                  0
# start_time                0
# end_time                  0
# start_station             0
# start_lat                19
# start_lon                19
# end_station               0
# end_lat                2506
# end_lon                2506
# bike_id                   0
# plan_duration             0
# trip_route_category       0
# passholder_type           0
# bike_type                 0
# dtype: int64

# %% [markdown]
# # Seaborn

# %%
import seaborn as sns

# %%
sns.scatterplot(x='bike_type',y='duration',data=df)
# Out:
# <Axes: xlabel='bike_type', ylabel='duration'>
