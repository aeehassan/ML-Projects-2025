# %% [markdown]
# # Data retrieval and Importations

# %%
pip install prophet
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from prophet import Prophet
# Out:
# Importing plotly failed. Interactive plots will not work.

# %%
# df = pd.read_csv(r'dataset.csv')
df = pd.read_csv('https://raw.githubusercontent.com/facebook/prophet/main/examples/example_wp_log_peyton_manning.csv')
df.head()
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File ~\miniconda3\envs\regression_env\Lib\urllib\request.py:1319, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1318 try:
# -> 1319     h.request(req.get_method(), req.selector, req.data, headers,
#    1320               encode_chunked=req.has_header('Transfer-encoding'))
#    1321 except OSError as err: # timeout error
#
# File ~\miniconda3\envs\regression_env\Lib\http\client.py:1338, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1337 """Send a complete request to the server."""
# -> 1338 self._send_request(method, url, body, headers, encode_chunked)
#
# File ~\miniconda3\envs\regression_env\Lib\http\client.py:1384, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
#    1383     body = _encode(body, 'body')
# ...

# %% [markdown]
# # Hidden

# %%
# df.drop(['Product','Store'], axis=1, inplace=True)

# %%
# df.describe().round(2)

# %%
# Set to datetime value
# df['Time Date'] = df['Time Date'].astype(str) 
# df['Year']  = df['Time Date'].str[0:4]
# df['Month'] = df['Time Date'].str[4:6]
# df['Day']   = df['Time Date'].str[6:8]

# df['ds'] = pd.to_datetime(df[['Year','Month','Day']])

# %%
# df
# Out:
#      Time Date        Value  Year Month Day
# 0      1012018  2926.000000  1012    01   8
# 1      2012018  2687.531000  2012    01   8
# 2      3012018  2793.000000  3012    01   8
# 3      4012018  2394.000000  4012    01   8
# 4      5012018  2660.000000  5012    01   8
# ...        ...          ...   ...   ...  ..
# 1075  12122020  3167.594500  1212    20  20
# 1076  13122020  3167.594500  1312    20  20
# 1077  14122020  3383.354511  1412    20  20
# 1078  15122020  2714.591329  1512    20  20
# 1079  16122020  2585.035107  1612    20  20
#
# [1080 rows x 5 columns]
