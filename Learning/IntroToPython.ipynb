# %%
FavouriteColours = ["pink", "blue", "gold", "amber"]
len(FavouriteColours)
# Out:
# 4

# %%
FavouriteColours[3]
# Out:
# 'amber'

# %%
# to check lenth of lists
len(FavouriteColours)
# Out:
# 4

# %%
FavouriteColours.append("beige")

# %%
len(FavouriteColours)
# Out:
# 5

# %%
FavouriteColours[1:5]
# Out:
# ['blue', 'gold', 'amber', 'beige']

# %%
FavouriteColours.extend(["black", "white", "maroon"])

# %%
len(FavouriteColours)
# Out:
# 8

# %%
FavouriteColours.pop(4)
# Out:
# 'beige'

# %%
FavouriteColours
# Out:
# ['pink', 'blue', 'gold', 'amber', 'black', 'white', 'maroon']

# %%
FavouriteColours[0] = "baby pink"

# %%
FavouriteColours
# Out:
# ['baby pink', 'blue', 'gold', 'amber', 'black', 'white', 'maroon']

# %%
rand_ages = (5,13,20,25,30,)

# %%
type(rand_ages)
# Out:
# tuple

# %%
type(FavouriteColours)
# Out:
# list

# %%
rand_ages2 = (1,2,3,4)
rand_ages + rand_ages2
# Out:
# (5, 13, 20, 25, 30, 1, 2, 3, 4)

# %%
Siblings_dict = {
    "name" : ["zubaida", "aisha", "rayyan"],
    "gender" : ["F", "F", "M"],
    "age" : [25, 19, 10]
}

# %%
Siblings_dict
# Out:
# {'name': ['zubaida', 'aisha', 'rayyan'],
#  'gender': ['F', 'F', 'M'],
#  'age': [25, 19, 10]}

# %%
top_students = {
    'names' : ['Abubakar','Munirat','Nafeesa','ABB'],
    'gpas' : [5.00, 5.00, 5.00, 5.00]
}

# %%
top_students
# Out:
# {'names': ['Abubakar', 'Munirat', 'Nafeesa', 'ABB'],
#  'gpas': [5.0, 5.0, 5.0, 5.0]}

# %%
Siblings_dict["name"].extend(["zayd", "zeitoun"])

# %%
Siblings_dict["name"]
# Out:
# ['zubaida', 'aisha', 'rayyan', 'zayd', 'zeitoun']

# %%
top_students['gpas'].extend([4.99,4.96,4.97])

# %%
top_students['gpas'][4]
# Out:
# 4.99

# %%
Siblings_dict["gender"].extend(["M", "F"])
Siblings_dict["age"].extend([25, 40])

# %%
Siblings_dict["FaveColour"]=  ["pink", "blue", "green", "gold", "purple"]

# %%
Siblings_dict
# Out:
# {'name': ['zubaida', 'aisha', 'rayyan', 'zayd', 'zeitoun'],
#  'gender': ['F', 'F', 'M', 'M', 'F'],
#  'age': [25, 19, 10, 25, 40],
#  'FaveColour': ['pink', 'blue', 'green', 'gold', 'purple']}

# %%
top_students['Reg. no'] = ['U22CS1001','U22CS1002','U22CS1003','U22CS1004']
top_students
# Out:
# {'names': ['Abubakar', 'Munirat', 'Nafeesa', 'ABB'],
#  'gpas': [5.0, 5.0, 5.0, 5.0, 4.99, 4.96, 4.97, 4.99, 4.96, 4.97],
#  'Reg. no': ['U22CS1001', 'U22CS1002', 'U22CS1003', 'U22CS1004']}
