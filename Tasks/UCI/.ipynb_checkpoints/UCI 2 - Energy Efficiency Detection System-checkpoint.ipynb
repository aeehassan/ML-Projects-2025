# %% [markdown]
# # Data retrieval

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in c:\users\user\miniconda3\envs\regression_env\lib\site-packages (3.1.5)
# Requirement already satisfied: et-xmlfile in c:\users\user\miniconda3\envs\regression_env\lib\site-packages (from openpyxl) (2.0.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
eed_df = pd.read_excel(r'energy efficiency detection webapp/ENB2012_data.xlsx')
eed_df
# Out:
#        X1     X2     X3      X4   X5  X6   X7  X8     Y1     Y2
# 0    0.98  514.5  294.0  110.25  7.0   2  0.0   0  15.55  21.33
# 1    0.98  514.5  294.0  110.25  7.0   3  0.0   0  15.55  21.33
# 2    0.98  514.5  294.0  110.25  7.0   4  0.0   0  15.55  21.33
# 3    0.98  514.5  294.0  110.25  7.0   5  0.0   0  15.55  21.33
# 4    0.90  563.5  318.5  122.50  7.0   2  0.0   0  20.84  28.28
# ..    ...    ...    ...     ...  ...  ..  ...  ..    ...    ...
# 763  0.64  784.0  343.0  220.50  3.5   5  0.4   5  17.88  21.40
# 764  0.62  808.5  367.5  220.50  3.5   2  0.4   5  16.54  16.88
# 765  0.62  808.5  367.5  220.50  3.5   3  0.4   5  16.44  17.11
# 766  0.62  808.5  367.5  220.50  3.5   4  0.4   5  16.48  16.61
# 767  0.62  808.5  367.5  220.50  3.5   5  0.4   5  16.64  16.03
#
# [768 rows x 10 columns]

# %%
eed_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   X1      768 non-null    float64
#  1   X2      768 non-null    float64
#  2   X3      768 non-null    float64
#  3   X4      768 non-null    float64
#  4   X5      768 non-null    float64
#  5   X6      768 non-null    int64
#  6   X7      768 non-null    float64
#  7   X8      768 non-null    int64
#  8   Y1      768 non-null    float64
#  9   Y2      768 non-null    float64
# dtypes: float64(8), int64(2)
# memory usage: 60.1 KB

# %%
eed_df.describe()
# Out:
#                X1          X2          X3          X4         X5          X6  \
# count  768.000000  768.000000  768.000000  768.000000  768.00000  768.000000
# mean     0.764167  671.708333  318.500000  176.604167    5.25000    3.500000
# std      0.105777   88.086116   43.626481   45.165950    1.75114    1.118763
# min      0.620000  514.500000  245.000000  110.250000    3.50000    2.000000
# 25%      0.682500  606.375000  294.000000  140.875000    3.50000    2.750000
# 50%      0.750000  673.750000  318.500000  183.750000    5.25000    3.500000
# 75%      0.830000  741.125000  343.000000  220.500000    7.00000    4.250000
# max      0.980000  808.500000  416.500000  220.500000    7.00000    5.000000
#
#                X7         X8          Y1          Y2
# count  768.000000  768.00000  768.000000  768.000000
# mean     0.234375    2.81250   22.307195   24.587760
# std      0.133221    1.55096   10.090204    9.513306
# min      0.000000    0.00000    6.010000   10.900000
# 25%      0.100000    1.75000   12.992500   15.620000
# 50%      0.250000    3.00000   18.950000   22.080000
# 75%      0.400000    4.00000   31.667500   33.132500
# max      0.400000    5.00000   43.100000   48.030000

# %% [markdown]
# # Data cleaning

# %% [markdown]
# ## Duplicates

# %%
eed_df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Missing values

# %%
eed_df.isna().sum()
# Out:
# X1    0
# X2    0
# X3    0
# X4    0
# X5    0
# X6    0
# X7    0
# X8    0
# Y1    0
# Y2    0
# dtype: int64

# %% [markdown]
# ## Outliers

# %%
# All columns are numerical
cols = eed_df.columns

for col in cols:
    plt.figure()
    sns.boxplot(eed_df[col], orient='h')
    plt.show()

# %% [markdown]
# # Data preprocessing

# %% [markdown]
# ## Standardization

# %%
from sklearn.preprocessing import StandardScaler

ss = StandardScaler()
model_inputs = eed_df.drop(['Y1','Y2'], axis=1).columns

eed_df[model_inputs] = ss.fit_transform(eed_df[model_inputs])
eed_df
# Out:
#            X1        X2        X3        X4   X5        X6        X7  \
# 0    2.041777 -1.785875 -0.561951 -1.470077  1.0 -1.341641 -1.760447
# 1    2.041777 -1.785875 -0.561951 -1.470077  1.0 -0.447214 -1.760447
# 2    2.041777 -1.785875 -0.561951 -1.470077  1.0  0.447214 -1.760447
# 3    2.041777 -1.785875 -0.561951 -1.470077  1.0  1.341641 -1.760447
# 4    1.284979 -1.229239  0.000000 -1.198678  1.0 -1.341641 -1.760447
# ..        ...       ...       ...       ...  ...       ...       ...
# 763 -1.174613  1.275625  0.561951  0.972512 -1.0  1.341641  1.244049
# 764 -1.363812  1.553943  1.123903  0.972512 -1.0 -1.341641  1.244049
# 765 -1.363812  1.553943  1.123903  0.972512 -1.0 -0.447214  1.244049
# 766 -1.363812  1.553943  1.123903  0.972512 -1.0  0.447214  1.244049
# 767 -1.363812  1.553943  1.123903  0.972512 -1.0  1.341641  1.244049
#
#            X8     Y1     Y2
# 0   -1.814575  15.55  21.33
# 1   -1.814575  15.55  21.33
# 2   -1.814575  15.55  21.33
# 3   -1.814575  15.55  21.33
# 4   -1.814575  20.84  28.28
# ..        ...    ...    ...
# 763  1.411336  17.88  21.40
# 764  1.411336  16.54  16.88
# 765  1.411336  16.44  17.11
# 766  1.411336  16.48  16.61
# 767  1.411336  16.64  16.03
#
# [768 rows x 10 columns]

# %% [markdown]
# ## Data splitting

# %%
from sklearn.model_selection import train_test_split

# %%
y = eed_df[["Y1","Y2"]]
X = eed_df.drop(["Y1","Y2"], axis=1)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %% [markdown]
# ## Model building

# %%
from sklearn.linear_model import LinearRegression

# %%
lr_model_two = LinearRegression()
lr_model_two.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ## Evaluation

# %%
y_pred = lr_model_two.predict(X_test)

# %%
from sklearn.metrics import r2_score, mean_absolute_error, root_mean_squared_error, mean_squared_error

# %%
r2 = r2_score(y_test, y_pred)
r2
# Out:
# 0.9035990988701139

# %%
mae = mean_absolute_error(y_test, y_pred)
mae
# Out:
# 2.2110408188717363

# %%
rmse = root_mean_squared_error(y_test, y_pred)
rmse
# Out:
# 3.0811409400543046

# %%
mse = mean_squared_error(y_test, y_pred)
mse
# Out:
# 9.501125731822928

# %%
# Rule of thumb check 
rmse > 0.2 * y.max()
# Out:
# Y1    False
# Y2    False
# dtype: bool

# %% [markdown]
# ## Test

# %%
X_test
# Out:
#            X1        X2        X3        X4   X5        X6        X7        X8
# 668 -1.363812  1.553943  1.123903  0.972512 -1.0 -1.341641  1.244049  0.120972
# 324 -0.985413  0.997307  0.000000  0.972512 -1.0 -1.341641  0.117363 -1.169393
# 624  2.041777 -1.785875 -0.561951 -1.470077  1.0 -1.341641  1.244049  0.120972
# 690  0.244383 -0.394284  0.561951 -0.655880  1.0  0.447214  1.244049  0.766154
# 473 -1.174613  1.275625  0.561951  0.972512 -1.0 -0.447214  0.117363  0.766154
# ..        ...       ...       ...       ...  ...       ...       ...       ...
# 554 -0.228616  0.162352 -1.685854  0.972512 -1.0  0.447214  1.244049 -1.169393
# 319 -0.512415  0.440670 -1.123903  0.972512 -1.0  1.341641  0.117363 -1.169393
# 594  0.244383 -0.394284  0.561951 -0.655880  1.0  0.447214  1.244049 -0.524211
# 6    1.284979 -1.229239  0.000000 -1.198678  1.0  0.447214 -1.760447 -1.814575
# 615 -0.985413  0.997307  0.000000  0.972512 -1.0  1.341641  1.244049 -0.524211
#
# [192 rows x 8 columns]

# %%
# Create test
my_test = pd.DataFrame({
    'X1': [0.62,0.92,0.77,0.75,0.98],
    'X2': [515,808,600,516.35,700.5],
    'X3': [248,400.5,300.4,298.65,310.5],
    'X4': [112.5,150.5,200.5,199.98,210.5],
    'X5': [3.6,4.0,5.0,6.0,6.8],
    'X6': [2,3,5,4,2],
    'X7': [0.0,0.1,0.35,0.4,0.22],
    'X8': [4,5,1,2,3]
})
my_test
# Out:
#      X1      X2      X3      X4   X5  X6    X7  X8
# 0  0.62  515.00  248.00  112.50  3.6   2  0.00   4
# 1  0.92  808.00  400.50  150.50  4.0   3  0.10   5
# 2  0.77  600.00  300.40  200.50  5.0   5  0.35   1
# 3  0.75  516.35  298.65  199.98  6.0   4  0.40   2
# 4  0.98  700.50  310.50  210.50  6.8   2  0.22   3

# %%
# Continuous cols
my_test_num_cols = my_test.columns

for col in my_test_num_cols:
    my_test[col] = ss.fit_transform(my_test[[col]])

my_test
# Out:
#          X1        X2        X3        X4        X5        X6        X7  \
# 0 -1.465533 -1.001068 -1.285508 -1.660101 -1.236083 -1.028992 -1.430359
# 1  0.873084  1.595312  1.796398 -0.647454 -0.902007 -0.171499 -0.761967
# 2 -0.296225 -0.247852 -0.226545  0.684975 -0.066815  1.543487  0.909013
# 3 -0.452133 -0.989106 -0.261911  0.671118  0.768376  0.685994  1.243209
# 4  1.340807  0.642715 -0.022432  0.951461  1.436529 -1.028992  0.040104
#
#          X8
# 0  0.707107
# 1  1.414214
# 2 -1.414214
# 3 -0.707107
# 4  0.000000

# %%
lr_model_two.predict(my_test)
# Out:
# array([[29.792101  , 35.97711914],
#        [ 6.42432233,  5.9951695 ],
#        [23.48170649, 26.10869541],
#        [34.48224416, 37.12488906],
#        [16.91469757, 17.15473524]])

# %% [markdown]
# ## Pairwise heatmap

# %%
corr_mx = eed_df.corr()
corr_mx = corr_mx.round(2)
# Select irrelevant cols
rel_cols = ['Y1','Y2']
corr_mx = corr_mx.loc['X1':'X8',rel_cols]
sns.heatmap(corr_mx, cmap='Greens', annot=True)
plt.title('Pairwise correlation heatmap')
plt.yticks(rotation=0)
plt.xticks([0.5,1.5], ['Heating Load','Cooling Load'])
plt.show()

# %% [markdown]
# ## Exporting the model

# %%
import joblib

# %%
joblib.dump((ss, lr_model_two), 'eed.pkl')
# Out:
# ['eed.pkl']
