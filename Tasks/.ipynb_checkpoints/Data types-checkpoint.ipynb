# %% [markdown]
# # A

# %%
# Lists for everybody's: names, institution, gender, and course of study 

names = ['Nureni Omowumi','Munirat Lawal','Aisha Ibrahim','Nafisat Abdulraheem','Abdulbadiu Bakare',
         'Abubakar Abdulkadir Hassan','Sadiq Shehu Musa','Oyeniran Tunde','Samson Popoola']
institution = ['AFIT','AFIT','AFIT','AFIT','KASU','KASU','Veritas','Fedpoly nass','Unijos']
gender = ['Female','Female','Female','Female','Male','Male','Male','Male','Male']
course_of_study = ['Computer Science','Computer Science','Computer Science','Computer Science','Computer Science',
                   'Computer Science','Computer Engineering','Electrical Electronic Engineering Technology','Accounting']

# %%
# Obtain and display the lengths of each list

print('Length of names =', len(names))
print('Length of institution =', len(institution))
print('Length of gender =', len(gender))
print('Length of course_of_study =', len(course_of_study))
# Out:
# Length of names = 9
# Length of institution = 9
# Length of gender = 9
# Length of course_of_study = 9

# %% [markdown]
# ## Indexing

# %% [markdown]
# ### 1

# %%
# Printing out the third element for each list i.e index 2

print('Third element for each list: \n')
print(names[2])
print(institution[2])
print(gender[2])
print(course_of_study[2])
# Out:
# Third element for each list:
#
# Aisha Ibrahim
# AFIT
# Female
# Computer Science

# %%
# Printing out the seventh element for each list i.e index 6

print('Seventh element for each list: \n')
print(names[6])
print(institution[6])
print(gender[6])
print(course_of_study[6])
# Out:
# Seventh element for each list:
#
# Sadiq Shehu Musa
# Veritas
# Male
# Computer Engineering

# %%
# Printing out the first element for each list i.e index 0

print('First element for each list: \n')
print(names[0])
print(institution[0])
print(gender[0])
print(course_of_study[0])
# Out:
# First element for each list:
#
# Nureni Omowumi
# AFIT
# Female
# Computer Science

# %%
# Printing out the ninth element for each list i.e index 8

print('Ninth element for each list: \n')
print(names[8])
print(institution[8])
print(gender[8])
print(course_of_study[8])
# Out:
# Ninth element for each list:
#
# Samson Popoola
# Unijos
# Male
# Accounting

# %%
# Printing out the sixth element for each list i.e index 5

print('Sixth element for each list: \n')
print(names[5])
print(institution[5])
print(gender[5])
print(course_of_study[5])
# Out:
# Sixth element for each list:
#
# Abubakar Abdulkadir Hassan
# KASU
# Male
# Computer Science

# %% [markdown]
# ### 2

# %%
# Printing out the second element for each list i.e index 1

print('Second element for each list: \n')
print(names[1])
print(institution[1])
print(gender[1])
print(course_of_study[1])
# Out:
# Second element for each list:
#
# Munirat Lawal
# AFIT
# Female
# Computer Science

# %%
# Printing out the fifth element for each list i.e index 4

print('Fifth element for each list: \n')
print(names[4])
print(institution[4])
print(gender[4])
print(course_of_study[4])
# Out:
# Fifth element for each list:
#
# Abdulbadiu Bakare
# KASU
# Male
# Computer Science

# %%
# Printing out the eight element for each list i.e index 7

print('Eight element for each list: \n')
print(names[7])
print(institution[7])
print(gender[7])
print(course_of_study[7])
# Out:
# Eight element for each list:
#
# Oyeniran Tunde
# Fedpoly nass
# Male
# Electrical Electronic Engineering Technology

# %%
# Printing out the fourth element for each list i.e index 3

print('Fourth element for each list: \n')
print(names[3])
print(institution[3])
print(gender[3])
print(course_of_study[3])
# Out:
# Fourth element for each list:
#
# Nafisat Abdulraheem
# AFIT
# Female
# Computer Science

# %%
# Printing out the first element for each list i.e index 0

print('First element for each list: \n')
print(names[0])
print(institution[0])
print(gender[0])
print(course_of_study[0])
# Out:
# First element for each list:
#
# Nureni Omowumi
# AFIT
# Female
# Computer Science

# %% [markdown]
# ### 3

# %%
# Printing out the ninth element for each list i.e index 8

print('Ninth element for each list: \n')
print(names[8])
print(institution[8])
print(gender[8])
print(course_of_study[8])
# Out:
# Ninth element for each list:
#
# Samson Popoola
# Unijos
# Male
# Accounting

# %%
# Printing out the third element for each list i.e index 2

print('Third element for each list: \n')
print(names[2])
print(institution[2])
print(gender[2])
print(course_of_study[2])
# Out:
# Third element for each list:
#
# Aisha Ibrahim
# AFIT
# Female
# Computer Science

# %%
# Printing out the sixth element for each list i.e index 5

print('Sixth element for each list: \n')
print(names[5])
print(institution[5])
print(gender[5])
print(course_of_study[5])
# Out:
# Sixth element for each list:
#
# Abubakar Abdulkadir Hassan
# KASU
# Male
# Computer Science

# %%
# Printing out the seventh element for each list i.e index 6

print('Seventh element for each list: \n')
print(names[6])
print(institution[6])
print(gender[6])
print(course_of_study[6])
# Out:
# Seventh element for each list:
#
# Sadiq Shehu Musa
# Veritas
# Male
# Computer Engineering

# %%
# Printing out the second element for each list i.e index 1

print('Second element for each list: \n')
print(names[1])
print(institution[1])
print(gender[1])
print(course_of_study[1])
# Out:
# Second element for each list:
#
# Munirat Lawal
# AFIT
# Female
# Computer Science

# %% [markdown]
# ### 4

# %%
# Printing out the fourth element for each list i.e index 3

print('Fourth element from each list: \n')
print(names[3])
print(institution[3])
print(gender[3])
print(course_of_study[3])
# Out:
# Fourth element from each list:
#
# Nafisat Abdulraheem
# AFIT
# Female
# Computer Science

# %%
# Printing out the first element for each list i.e index 0

print('First element from each list: \n')
print(names[0])
print(institution[0])
print(gender[0])
print(course_of_study[0])
# Out:
# First element from each list:
#
# Nureni Omowumi
# AFIT
# Female
# Computer Science

# %%
# Printing out the eighth element for each list i.e index 7

print('Eighth element from each list: \n')
print(names[7])
print(institution[7])
print(gender[7])
print(course_of_study[7])
# Out:
# Eighth element from each list:
#
# Oyeniran Tunde
# Fedpoly nass
# Male
# Electrical Electronic Engineering Technology

# %%
# Printing out the third element for each list i.e index 2

print('Third element from each list: \n')
print(names[2])
print(institution[2])
print(gender[2])
print(course_of_study[2])
# Out:
# Third element from each list:
#
# Aisha Ibrahim
# AFIT
# Female
# Computer Science

# %%
# Printing out the seventh element for each list i.e index 6

print('Seventh element from each list: \n')
print(names[6])
print(institution[6])
print(gender[6])
print(course_of_study[6])
# Out:
# Seventh element from each list:
#
# Sadiq Shehu Musa
# Veritas
# Male
# Computer Engineering

# %% [markdown]
# ## Index slicing to print out alike items

# %% [markdown]
# ### Institutions

# %%
print(institution[0:4])
# Out:
# ['AFIT', 'AFIT', 'AFIT', 'AFIT']

# %%
print(institution[4:6])
# Out:
# ['KASU', 'KASU']

# %%
# They represent institutions outside Kaduna state. Thus, they're alike
print(institution[6:10])
# Out:
# ['Veritas', 'Fedpoly nass', 'Unijos']

# %% [markdown]
# ### Course of Study

# %%
print(course_of_study[0:6])
# Out:
# ['Computer Science', 'Computer Science', 'Computer Science', 'Computer Science', 'Computer Science', 'Computer Science']

# %%
# These elements are engineering courses. Thus, they are alike
print(course_of_study[6:8])
# Out:
# ['Computer Engineering', 'Electrical Electronic Engineering Technology']

# %% [markdown]
# ### Genders

# %%
print(gender[0:4])
# Out:
# ['Female', 'Female', 'Female', 'Female']

# %%
print(gender[4:10])
# Out:
# ['Male', 'Male', 'Male', 'Male', 'Male']

# %% [markdown]
# # B

# %%
# srs reps. the School Record System dictionary
# It will contain a min. of 20 students
# For Sex key: M = Male and F = Female

srs = {
    'Name' : ['Munirat Lawal','Abubakar Abdulkadir','Sadiq Musa','Abdullahi Abdullahi','Aisha Ibrahim',
              'Nafeesa Abdurraheem','Muhammad Yusuf','Rayyan Lawal','Mahir Ibrahim','Aisha Usman',
              'Alamu Ibrahim','Muhammad Abbas','Aliyu Muhammad','Nura Abubakar','Yusuf Nureini',
              'Cristiano Ronaldo','Abdulbadiu Bakare','Zariyat Adeniran','Asmau Adeniran','Khadija Aliyu'],
    'Department': ['Computer Engineering','Computer Science','Computer Science','Computer Science','Cybersecurity',
                   'Computer Science','Computer Science','Cybersecurity','Cybersecurity','Cybersecurity',
                   'Cybersecurity','Computer Engineering','Computer Science','Computer Engineering','Computer Science',
                   'Computer Science','Computer Science','Computer Engineering','Computer Engineering','Computer Engineering'],
    'Date of Birth' : ['06-12-2004','18-10-2004','03-09-2002','04-10-2000','08-06-2004',
                       '11-08-2004','15-10-2003','11-09-2004','20-07-2005','21-09-2004',
                       '12-12-2002','15-12-2002','06-12-2001','06-12-2004','06-11-2006',
                       '06-11-2004','09-09-2004','07-02-2002','25-05-2004','09-03-2001'],
    'Phone Number' : ['07012345678','08023456789','08034567890','07045678901','08056789012',
                      '07067890123','08078901234','07089012345','08090123456','08101234567',
                      '08112345678','08123456789','08134567890','08145678901','08156789012',
                      '08167890123','08178901234','08189012345','08190123456','09091234567'],
    'Sex' : ['F','M','M','M','F',
             'F','M','M','M','F',
             'M','M','M','M','M',
             'M','M','F','F','F'],
    'Hobby' : ['Anime','Anime','Reading','Gaming','Sports',
               'Movies','Reading','Sports','Sleeping','Coding',
               'Anime','Reading','Movies','Sports','Gaming',
               'Coding','Drawing','Sleeping','Eating','Sports']
}

# %%
srs
# Out:
# {'Name': ['Munirat Lawal',
#   'Abubakar Abdulkadir',
#   'Sadiq Musa',
#   'Abdullahi Abdullahi',
#   'Aisha Ibrahim',
#   'Nafeesa Abdurraheem',
#   'Muhammad Yusuf',
#   'Rayyan Lawal',
#   'Mahir Ibrahim',
#   'Aisha Usman',
#   'Alamu Ibrahim',
#   'Muhammad Abbas',
#   'Aliyu Muhammad',
#   'Nura Abubakar',
#   'Yusuf Nureini',
#   'Cristiano Ronaldo',
#   'Abdulbadiu Bakare',
#   'Zariyat Adeniran',
#   'Asmau Adeniran',
#   'Khadija Aliyu'],
#  'Department': ['Computer Engineering',
#   'Computer Science',
#   'Computer Science',
#   'Computer Science',
#   'Cybersecurity',
#   'Computer Science',
#   'Computer Science',
#   'Cybersecurity',
#   'Cybersecurity',
#   'Cybersecurity',
#   'Cybersecurity',
#   'Computer Engineering',
#   'Computer Science',
#   'Computer Engineering',
#   'Computer Science',
#   'Computer Science',
#   'Computer Science',
#   'Computer Engineering',
#   'Computer Engineering',
#   'Computer Engineering'],
#  'Date of Birth': ['06-12-2004',
# ...

# %% [markdown]
# ### Adding the new keys: Email, Age, and CGPA

# %%
# Add Email key for each student

srs['Email'] = ['student1@gmail.com','student2@gmail.com','student3@gmail.com','student4@gmail.com','student5@gmail.com',
                'student6@gmail.com','student7@gmail.com','student8@gmail.com','student9@gmail.com','student10@gmail.com',
                'student11@gmail.com','student12@gmail.com','student13@gmail.com','student14@gmail.com','student15@gmail.com',
                'student16@gmail.com','student17@gmail.com','student18@gmail.com','student19@gmail.com','student20@gmail.com']

# %%
# Add Age key for each student

srs['Age'] = [20,20,22,24,21,
              20,21,20,20,20,
              22,22,23,20,18,
              20,20,23,21,24]

# %%
# Add CGPA key for each student

srs['CGPA'] = [4.99,4.97,4.50,4.48,4.49,
               4.85,3.89,4.98,4.88,4.32,
               4.42,4.05,4.23,4.33,4.50,
               4.99,4.97,3.95,4.89,4.85]

# %%
srs
# Out:
# {'Name': ['Munirat Lawal',
#   'Abubakar Abdulkadir',
#   'Sadiq Musa',
#   'Abdullahi Abdullahi',
#   'Aisha Ibrahim',
#   'Nafeesa Abdurraheem',
#   'Muhammad Yusuf',
#   'Rayyan Lawal',
#   'Mahir Ibrahim',
#   'Aisha Usman',
#   'Alamu Ibrahim',
#   'Muhammad Abbas',
#   'Aliyu Muhammad',
#   'Nura Abubakar',
#   'Yusuf Nureini',
#   'Cristiano Ronaldo',
#   'Abdulbadiu Bakare',
#   'Zariyat Adeniran',
#   'Asmau Adeniran',
#   'Khadija Aliyu'],
#  'Department': ['Computer Engineering',
#   'Computer Science',
#   'Computer Science',
#   'Computer Science',
#   'Cybersecurity',
#   'Computer Science',
#   'Computer Science',
#   'Cybersecurity',
#   'Cybersecurity',
#   'Cybersecurity',
#   'Cybersecurity',
#   'Computer Engineering',
#   'Computer Science',
#   'Computer Engineering',
#   'Computer Science',
#   'Computer Science',
#   'Computer Science',
#   'Computer Engineering',
#   'Computer Engineering',
#   'Computer Engineering'],
#  'Date of Birth': ['06-12-2004',
# ...

# %%
# Removing the key hobby from srs
srs.pop('Hobby')
# Out:
# ['Anime',
#  'Anime',
#  'Reading',
#  'Gaming',
#  'Sports',
#  'Movies',
#  'Reading',
#  'Sports',
#  'Sleeping',
#  'Coding',
#  'Anime',
#  'Reading',
#  'Movies',
#  'Sports',
#  'Gaming',
#  'Coding',
#  'Drawing',
#  'Sleeping',
#  'Eating',
#  'Sports']

# %% [markdown]
# ### Removing 5 students along with their info from srs

# %%
# Removing student 20 - 'Khadija Aliyu'
# This represents the student at index 19
srs['Name'].pop(19)
srs['Department'].pop(19)
srs['Date of Birth'].pop(19)
srs['Phone Number'].pop(19)
srs['Sex'].pop(19)
srs['Email'].pop(19)
srs['Age'].pop(19)
srs['CGPA'].pop(19)
# Out:
# 4.85

# %%
# Removing student 19 - 'Asmau Adeniran'
# This represents the student at index 18
srs['Name'].pop(18)
srs['Department'].pop(18)
srs['Date of Birth'].pop(18)
srs['Phone Number'].pop(18)
srs['Sex'].pop(18)
srs['Email'].pop(18)
srs['Age'].pop(18)
srs['CGPA'].pop(18)
# Out:
# 4.89

# %%
# Removing student 7 - 'Muhammad Yusuf'
# This represents the student at index 6
srs['Name'].pop(6)
srs['Department'].pop(6)
srs['Date of Birth'].pop(6)
srs['Phone Number'].pop(6)
srs['Sex'].pop(6)
srs['Email'].pop(6)
srs['Age'].pop(6)
srs['CGPA'].pop(6)
# Out:
# 3.89

# %%
# Removing student 9 - 'Mahir Ibrahim'
# This represents the student at index 7 because student 7 that was popped messed with his position in the list
srs['Name'].pop(7)
srs['Department'].pop(7)
srs['Date of Birth'].pop(7)
srs['Phone Number'].pop(7)
srs['Sex'].pop(7)
srs['Email'].pop(7)
srs['Age'].pop(7)
srs['CGPA'].pop(7)
# Out:
# 4.88

# %%
# Removing student 4 - 'Abdullahi Abdullahi'
# This represents the student at index 3
srs['Name'].pop(3)
srs['Department'].pop(3)
srs['Date of Birth'].pop(3)
srs['Phone Number'].pop(3)
srs['Sex'].pop(3)
srs['Email'].pop(3)
srs['Age'].pop(3)
srs['CGPA'].pop(3)
# Out:
# 4.48

# %% [markdown]
# ### Data type of each key's values in srs

# %%
# Obtain the data type of key's values using a for loop so as to minimize redundancy

for key in srs:
    print(f'{key}: ', type(srs[key][0]))
# Out:
# Name:  <class 'str'>
# Department:  <class 'str'>
# Date of Birth:  <class 'str'>
# Phone Number:  <class 'str'>
# Sex:  <class 'str'>
# Email:  <class 'str'>
# Age:  <class 'int'>
# CGPA:  <class 'float'>

# %% [markdown]
# ### Number of students left

# %%
len(srs['Name'])
# Out:
# 15

# %% [markdown]
# ### Number of details each student has

# %%
len(srs)
# Out:
# 8
