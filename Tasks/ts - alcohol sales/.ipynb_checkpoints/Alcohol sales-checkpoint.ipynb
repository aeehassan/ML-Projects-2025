# %% [markdown]
# # Data retrieval

# %%
# pip install notebook
# pip install ipywidgets

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r'Alcohol_Sales.csv')

# %%
df.head()
# Out:
#          DATE  S4248SM144NCEN
# 0  1992-01-01            3459
# 1  1992-02-01            3458
# 2  1992-03-01            4002
# 3  1992-04-01            4564
# 4  1992-05-01            4221

# %%
df.tail()
# Out:
#            DATE  S4248SM144NCEN
# 320  2018-09-01           12396
# 321  2018-10-01           13914
# 322  2018-11-01           14174
# 323  2018-12-01           15504
# 324  2019-01-01           10718

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 325 entries, 0 to 324
# Data columns (total 2 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   DATE            325 non-null    object
#  1   S4248SM144NCEN  325 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 5.2+ KB

# %% [markdown]
# # Data cleaning

# %%
# Missing values
df.isna().sum()
# Out:
# DATE              0
# S4248SM144NCEN    0
# dtype: int64

# %%
# Duplicate entries 
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # Data preprocessing

# %%
# Check line plot
plt.figure(figsize=(12,10))
sns.lineplot(data=df, x='DATE', y='S4248SM144NCEN', color='green')
plt.title('Product sales')
plt.xlabel('Date')
plt.ylabel('Sales')
# Out:
# Text(0, 0.5, 'Sales')

# %%
df.rename(columns={'DATE':'ds', 'S4248SM144NCEN':'y'}, inplace=True)
df
# Out:
#              ds      y
# 0    1992-01-01   3459
# 1    1992-02-01   3458
# 2    1992-03-01   4002
# 3    1992-04-01   4564
# 4    1992-05-01   4221
# ..          ...    ...
# 320  2018-09-01  12396
# 321  2018-10-01  13914
# 322  2018-11-01  14174
# 323  2018-12-01  15504
# 324  2019-01-01  10718
#
# [325 rows x 2 columns]

# %%
# Convert ds to a pandas date object
df['ds'] = pd.to_datetime(df['ds'])
df
# Out:
#             ds      y
# 0   1992-01-01   3459
# 1   1992-02-01   3458
# 2   1992-03-01   4002
# 3   1992-04-01   4564
# 4   1992-05-01   4221
# ..         ...    ...
# 320 2018-09-01  12396
# 321 2018-10-01  13914
# 322 2018-11-01  14174
# 323 2018-12-01  15504
# 324 2019-01-01  10718
#
# [325 rows x 2 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 325 entries, 0 to 324
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ds      325 non-null    datetime64[ns]
#  1   y       325 non-null    int64
# dtypes: datetime64[ns](1), int64(1)
# memory usage: 5.2 KB

# %% [markdown]
# # Data splitting

# %%
# Train reps 80% of dataset = 260
train = df.iloc[:260, :]
# Test reps 20% of dataset = 65
test = df.iloc[260:, :]

# %%
print(train.shape, test.shape)
# Out:
# (260, 2) (65, 2)

# %%
train
# Out:
#             ds      y
# 0   1992-01-01   3459
# 1   1992-02-01   3458
# 2   1992-03-01   4002
# 3   1992-04-01   4564
# 4   1992-05-01   4221
# ..         ...    ...
# 255 2013-04-01  10493
# 256 2013-05-01  12218
# 257 2013-06-01  11385
# 258 2013-07-01  11186
# 259 2013-08-01  11462
#
# [260 rows x 2 columns]

# %%
test
# Out:
#             ds      y
# 260 2013-09-01  10494
# 261 2013-10-01  11540
# 262 2013-11-01  11138
# 263 2013-12-01  12709
# 264 2014-01-01   8557
# ..         ...    ...
# 320 2018-09-01  12396
# 321 2018-10-01  13914
# 322 2018-11-01  14174
# 323 2018-12-01  15504
# 324 2019-01-01  10718
#
# [65 rows x 2 columns]

# %% [markdown]
# # Model building

# %%
from prophet import Prophet

# %%
model = Prophet()
model.fit(train)
# Out:
# 20:29:08 - cmdstanpy - INFO - Chain [1] start processing
# 20:29:08 - cmdstanpy - INFO - Chain [1] done processing

# %%
future = test[['ds']]
forecast = model.predict(future)

# %%
forecast
# Out:
#            ds         trend    yhat_lower    yhat_upper   trend_lower  \
# 0  2013-09-01  10680.834411   9992.066430  10975.582016  10680.834411
# 1  2013-10-01  10710.114795  10395.503279  11419.296385  10710.114795
# 2  2013-11-01  10740.371192  10418.803897  11424.464755  10740.217506
# 3  2013-12-01  10769.651575  11351.076935  12389.717269  10769.069241
# 4  2014-01-01  10799.907972   8688.959006   9708.781147  10798.886075
# ..        ...           ...           ...           ...           ...
# 60 2018-09-01  12463.033771  11800.877428  12781.150973  12356.473522
# 61 2018-10-01  12492.314154  12140.225719  13206.060809  12384.169676
# 62 2018-11-01  12522.570551  12274.552123  13245.981124  12412.896856
# 63 2018-12-01  12551.850935  13105.340528  14091.069951  12439.063700
# 64 2019-01-01  12582.107331  10481.693045  11492.487935  12465.778998
#
#      trend_upper  additive_terms  additive_terms_lower  additive_terms_upper  \
# 0   10680.834411     -172.102635           -172.102635           -172.102635
# 1   10710.138250      192.582588            192.582588            192.582588
# 2   10740.747216      206.177015            206.177015            206.177015
# 3   10770.466771     1079.392510           1079.392510           1079.392510
# 4   10801.313644    -1579.881112          -1579.881112          -1579.881112
# ..           ...             ...                   ...                   ...
# 60  12568.568044     -163.509271           -163.509271           -163.509271
# 61  12601.792218      163.288340            163.288340            163.288340
# 62  12636.212154      220.894629            220.894629            220.894629
# 63  12668.001023     1054.685924           1054.685924           1054.685924
# 64  12700.823549    -1595.232540          -1595.232540          -1595.232540
#
#          yearly  yearly_lower  yearly_upper  multiplicative_terms  \
# 0   -172.102635   -172.102635   -172.102635                   0.0
# 1    192.582588    192.582588    192.582588                   0.0
# 2    206.177015    206.177015    206.177015                   0.0
# 3   1079.392510   1079.392510   1079.392510                   0.0
# 4  -1579.881112  -1579.881112  -1579.881112                   0.0
# ..          ...           ...           ...                   ...
# 60  -163.509271   -163.509271   -163.509271                   0.0
# 61   163.288340    163.288340    163.288340                   0.0
# 62   220.894629    220.894629    220.894629                   0.0
# 63  1054.685924   1054.685924   1054.685924                   0.0
# 64 -1595.232540  -1595.232540  -1595.232540                   0.0
#
#     multiplicative_terms_lower  multiplicative_terms_upper          yhat
# 0                          0.0                         0.0  10508.731776
# 1                          0.0                         0.0  10902.697383
# 2                          0.0                         0.0  10946.548207
# 3                          0.0                         0.0  11849.044085
# 4                          0.0                         0.0   9220.026860
# ..                         ...                         ...           ...
# 60                         0.0                         0.0  12299.524500
# 61                         0.0                         0.0  12655.602494
# 62                         0.0                         0.0  12743.465180
# 63                         0.0                         0.0  13606.536858
# 64                         0.0                         0.0  10986.874791
#
# [65 rows x 16 columns]

# %%
from prophet.plot import plot_plotly

fig = plot_plotly(model, forecast)
fig.show()

# %%
model.plot_components(forecast)
fig.show()

# %% [markdown]
# # Performance metrics

# %%
from sklearn.metrics import mean_absolute_error, root_mean_squared_error, mean_squared_error

# %%
# Extract y-hat and y from the test data
actual_values = test['y']
predicted_values = forecast['yhat']
# Store in a df
y = pd.DataFrame([actual_values,predicted_values], columns=['true','pred'])
y
# Out:
#       true  pred
# y      NaN   NaN
# yhat   NaN   NaN
