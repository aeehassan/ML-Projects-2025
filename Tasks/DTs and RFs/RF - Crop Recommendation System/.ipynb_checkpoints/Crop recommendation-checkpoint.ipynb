# %% [markdown]
# # Data retrieval

# %% [markdown]
# This dataset is for crop recommendation and the dataset seems to be extremely good.
#
# **Key features**
# - It has soil nutrients (N, P, K) and environmental factors like temperature, humidity, pH, and rainfall.
# - The goal is to use these features to suggest the best crop, improving yield, resource use, and sustainability.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# It is most likely:
# - Synthetic
# - Too clean

# %%
df = pd.read_csv(r'Crop_Recommendation.csv')
df.head()
# Out:
#    Nitrogen  Phosphorus  Potassium  Temperature   Humidity  pH_Value  \
# 0        90          42         43    20.879744  82.002744  6.502985
# 1        85          58         41    21.770462  80.319644  7.038096
# 2        60          55         44    23.004459  82.320763  7.840207
# 3        74          35         40    26.491096  80.158363  6.980401
# 4        78          42         42    20.130175  81.604873  7.628473
#
#      Rainfall  Crop
# 0  202.935536  Rice
# 1  226.655537  Rice
# 2  263.964248  Rice
# 3  242.864034  Rice
# 4  262.717340  Rice

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2200 entries, 0 to 2199
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Nitrogen     2200 non-null   int64
#  1   Phosphorus   2200 non-null   int64
#  2   Potassium    2200 non-null   int64
#  3   Temperature  2200 non-null   float64
#  4   Humidity     2200 non-null   float64
#  5   pH_Value     2200 non-null   float64
#  6   Rainfall     2200 non-null   float64
#  7   Crop         2200 non-null   object
# dtypes: float64(4), int64(3), object(1)
# memory usage: 137.6+ KB

# %%
df.describe()
# Out:
#           Nitrogen   Phosphorus    Potassium  Temperature     Humidity  \
# count  2200.000000  2200.000000  2200.000000  2200.000000  2200.000000
# mean     50.551818    53.362727    48.149091    25.616244    71.481779
# std      36.917334    32.985883    50.647931     5.063749    22.263812
# min       0.000000     5.000000     5.000000     8.825675    14.258040
# 25%      21.000000    28.000000    20.000000    22.769375    60.261953
# 50%      37.000000    51.000000    32.000000    25.598693    80.473146
# 75%      84.250000    68.000000    49.000000    28.561654    89.948771
# max     140.000000   145.000000   205.000000    43.675493    99.981876
#
#           pH_Value     Rainfall
# count  2200.000000  2200.000000
# mean      6.469480   103.463655
# std       0.773938    54.958389
# min       3.504752    20.211267
# 25%       5.971693    64.551686
# 50%       6.425045    94.867624
# 75%       6.923643   124.267508
# max       9.935091   298.560117

# %% [markdown]
# # Data cleaning

# %% [markdown]
# ### Missing values

# %%
df.isna().sum()
# Out:
# Nitrogen       0
# Phosphorus     0
# Potassium      0
# Temperature    0
# Humidity       0
# pH_Value       0
# Rainfall       0
# Crop           0
# dtype: int64

# %% [markdown]
# ### Duplicates

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### Outliers

# %%
features = df.columns.drop('Crop')

for i in features:
    sns.boxplot(df[i], orient='h')
    plt.title(f'{i} plot')
    plt.show()

# %%
from scipy.stats.mstats import winsorize

# %%
# Outlier types
mild = ['Phosphorus','Temperature','Humidity','pH_Value','Rainfall']
med = ['Potassium']

for i in features:
    if i in mild:
        df[i] = winsorize(df[i], limits=[0.01,0.01])
    else:
        df[i] = winsorize(df[i], limits=[0.05,0.05])

# %%
df
# Out:
#       Nitrogen  Phosphorus  Potassium  Temperature   Humidity  pH_Value  \
# 0           90          42         43    20.879744  82.002744  6.502985
# 1           85          58         41    21.770462  80.319644  7.038096
# 2           60          55         44    23.004459  82.320763  7.840207
# 3           74          35         40    26.491096  80.158363  6.980401
# 4           78          42         42    20.130175  81.604873  7.628473
# ...        ...         ...        ...          ...        ...       ...
# 2195       107          34         32    26.774637  66.413269  6.780064
# 2196        99          15         27    27.417112  56.636362  6.086922
# 2197       116          33         30    24.131797  67.225123  6.362608
# 2198       116          32         34    26.272418  52.127394  6.758793
# 2199       104          18         30    23.603016  60.396475  6.779833
#
#         Rainfall    Crop
# 0     202.935536    Rice
# 1     226.655537    Rice
# ...

# %% [markdown]
# # Data preprocessing

# %% [markdown]
# ### Normalization
#
# Normalization means scaling values so they all fall between 0 and 1.
# I used it here because my dataset doesn’t have a wide range, so StandardScaler isn’t really needed — normalization just makes more sense in this case.

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
mm = MinMaxScaler()

# %%
df[features] = mm.fit_transform(df[features])

# %%
df
# Out:
#       Nitrogen  Phosphorus  Potassium  Temperature  Humidity  pH_Value  \
# 0     0.767857    0.262774   0.152174     0.312559  0.816938  0.459600
# 1     0.723214    0.379562   0.141304     0.343315  0.796348  0.589080
# 2     0.500000    0.357664   0.157609     0.385923  0.820829  0.783165
# 3     0.625000    0.211679   0.135870     0.506314  0.794375  0.575119
# 4     0.660714    0.262774   0.146739     0.286677  0.812071  0.731932
# ...        ...         ...        ...          ...       ...       ...
# 2195  0.919643    0.204380   0.092391     0.516104  0.626220  0.526644
# 2196  0.848214    0.065693   0.065217     0.538288  0.506612  0.358926
# 2197  1.000000    0.197080   0.081522     0.424849  0.636152  0.425633
# 2198  1.000000    0.189781   0.103261     0.498763  0.451450  0.521497
# 2199  0.892857    0.087591   0.081522     0.406591  0.552612  0.526588
#
#       Rainfall    Crop
# 0     0.735684    Rice
# 1     0.832079    Rice
# 2     0.983696    Rice
# ...

# %% [markdown]
# ### Label encoding

# %%
# To encode our categorical data - target
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
df['Crop'] = le.fit_transform(df['Crop'])

# %%
df
# Out:
#       Nitrogen  Phosphorus  Potassium  Temperature  Humidity  pH_Value  \
# 0     0.767857    0.262774   0.152174     0.312559  0.816938  0.459600
# 1     0.723214    0.379562   0.141304     0.343315  0.796348  0.589080
# 2     0.500000    0.357664   0.157609     0.385923  0.820829  0.783165
# 3     0.625000    0.211679   0.135870     0.506314  0.794375  0.575119
# 4     0.660714    0.262774   0.146739     0.286677  0.812071  0.731932
# ...        ...         ...        ...          ...       ...       ...
# 2195  0.919643    0.204380   0.092391     0.516104  0.626220  0.526644
# 2196  0.848214    0.065693   0.065217     0.538288  0.506612  0.358926
# 2197  1.000000    0.197080   0.081522     0.424849  0.636152  0.425633
# 2198  1.000000    0.189781   0.103261     0.498763  0.451450  0.521497
# 2199  0.892857    0.087591   0.081522     0.406591  0.552612  0.526588
#
#       Rainfall  Crop
# 0     0.735684    20
# 1     0.832079    20
# 2     0.983696    20
# 3     0.897948    20
# ...

# %% [markdown]
# # Data splitting

# %%
from sklearn.model_selection import train_test_split

# %%
X = df[features]
y = df['Crop']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, stratify=y)

# %%
print(X_train.shape, y_train.shape, X_test.shape, y_test.shape)
# Out:
# (1540, 7) (1540,) (660, 7) (660,)

# %% [markdown]
# ### Class imbalance

# %%
y.value_counts()
# Out:
# Crop
# 20    100
# 11    100
# 3     100
# 9     100
# 18    100
# 13    100
# 14    100
# 2     100
# 10    100
# 19    100
# 1     100
# 12    100
# 7     100
# 21    100
# 15    100
# 0     100
# 16    100
# 17    100
# 4     100
# 6     100
# 8     100
# 5     100
# Name: count, dtype: int64

# %% [markdown]
# # Model building A

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
# The more the depth of the tree, the more prone it is to overfitting 
rf = RandomForestClassifier(n_estimators=70, max_depth=4, random_state=42)
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=4, n_estimators=70, random_state=42)

# %%
# Check list of all hyperparameters RF has
# ?RandomForestClassifier
# Out:
# Init signature:
# RandomForestClassifier(
#     n_estimators=100,
#     *,
#     criterion='gini',
#     max_depth=None,
#     min_samples_split=2,
#     min_samples_leaf=1,
#     min_weight_fraction_leaf=0.0,
#     max_features='sqrt',
#     max_leaf_nodes=None,
#     min_impurity_decrease=0.0,
#     bootstrap=True,
#     oob_score=False,
#     n_jobs=None,
#     random_state=None,
#     verbose=0,
#     warm_start=False,
#     class_weight=None,
#     ccp_alpha=0.0,
#     max_samples=None,
#     monotonic_cst=None,
# )
# Docstring:
# A random forest classifier.
#
# A random forest is a meta estimator that fits a number of decision tree
# classifiers on various sub-samples of the dataset and uses averaging to
# improve the predictive accuracy and control over-fitting.
# Trees in the forest use the best split strategy, i.e. equivalent to passing
# `splitter="best"` to the underlying :class:`~sklearn.tree.DecisionTreeClassifier`.
# ...

# %% [markdown]
# # Evaluation A

# %%
from sklearn.metrics import precision_score, recall_score, f1_score, classification_report, confusion_matrix

# %%
y_pred = rf.predict(X_test)

# %%
acc = rf.score(X_test, y_test)
pre = precision_score(y_test, y_pred, average='macro')
re = recall_score(y_test, y_pred, average='macro')
f1 = f1_score(y_test, y_pred, average='macro')
cr = classification_report(y_test, y_pred)

# %%
print(f"Accuracy Score       : {acc:.4f}")
print(f"Precision Score      : {pre:.4f}")
print(f"Recall Score         : {re:.4f}")
print(f"F1 Score             : {f1:.4f}")
print("\nClassification Report:\n")
print(cr)
# Out:
# Accuracy Score       : 0.9742
# Precision Score      : 0.9754
# Recall Score         : 0.9742
# F1 Score             : 0.9740
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        30
#            1       1.00      1.00      1.00        30
#            2       0.88      0.97      0.92        30
#            3       1.00      1.00      1.00        30
#            4       1.00      1.00      1.00        30
#            5       1.00      1.00      1.00        30
#            6       0.97      1.00      0.98        30
#            7       1.00      1.00      1.00        30
#            8       0.86      1.00      0.92        30
#            9       1.00      1.00      1.00        30
#           10       0.93      0.90      0.92        30
#           11       0.97      0.97      0.97        30
#           12       1.00      1.00      1.00        30
#           13       0.89      0.80      0.84        30
# ...
